# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load birds dataset

# %%
birds = pd.read_csv("birds.csv")

# %% [markdown]
# ### First 15 observations

# %%
birds.head(15)
# Out:
#                             Name          ScientificName  \
# 0   Black-bellied whistling-duck  Dendrocygna autumnalis
# 1         Fulvous whistling-duck     Dendrocygna bicolor
# 2                     Snow goose      Anser caerulescens
# 3                   Ross's goose            Anser rossii
# 4    Greater white-fronted goose         Anser albifrons
# 5                          Brant         Branta bernicla
# 6                 Cackling goose       Branta hutchinsii
# 7                   Canada goose       Branta canadensis
# 8                      Mute swan             Cygnus olor
# 9                 Trumpeter swan       Cygnus buccinator
# 10                   Tundra swan      Cygnus columbianus
# 11                     Wood duck              Aix sponsa
# 12                      Garganey     Spatula querquedula
# 13              Blue-winged teal         Spatula discors
# 14                 Cinnamon teal      Spatula cyanoptera
#
# ...

# %% [markdown]
# ### Last 15 Observations

# %%
birds.tail(15)
# Out:
#                              Name             ScientificName  \
# 428  Black-throated green warbler           Setophaga virens
# 429                Canada warbler      Cardellina canadensis
# 430              Wilson's warbler         Cardellina pusilla
# 431              Painted redstart           Myioborus pictus
# 432                Summer tanager              Piranga rubra
# 433               Scarlet tanager           Piranga olivacea
# 434               Western tanager        Piranga ludoviciana
# 435             Northern cardinal      Cardinalis cardinalis
# 436        Rose-breasted grosbeak    Pheucticus ludovicianus
# 437         Black-headed grosbeak  Pheucticus melanocephalus
# 438                 Blue grosbeak         Passerina caerulea
# 439                Lazuli bunting           Passerina amoena
# 440                Indigo bunting           Passerina cyanea
# 441               Painted bunting            Passerina ciris
# ...

# %% [markdown]
# ### DataFrame shape

# %%
birds.shape
# Out:
# (443, 13)

# %% [markdown]
# ### DataFrame columns

# %%
birds.columns
# Out:
# Index(['Name', 'ScientificName', 'Category', 'Order', 'Family', 'Genus',
#        'ConservationStatus', 'MinLength', 'MaxLength', 'MinBodyMass',
#        'MaxBodyMass', 'MinWingspan', 'MaxWingspan'],
#       dtype='object')

# %% [markdown]
# ### DataFrame info

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %% [markdown]
# ### Dataframe Descriptive statistics

# %%
birds.describe()
# Out:
#         MinLength   MaxLength  MinBodyMass   MaxBodyMass  MinWingspan  \
# count  443.000000  443.000000   443.000000    443.000000   443.000000
# mean    28.536682   35.441986   327.938262    667.009752    58.557901
# std     20.319887   27.539772   779.680106   1655.682564   104.602369
# min      7.000000    8.900000     2.000000      3.000000     8.000000
# 25%     13.750000   16.000000    18.000000     28.000000    23.000000
# 50%     20.500000   25.000000    55.000000     89.000000    38.000000
# 75%     39.000000   46.000000   332.000000    593.000000    72.750000
# max    138.000000  180.000000  9200.000000  14300.000000  1800.000000
#
#        MaxWingspan
# count   443.000000
# mean     67.524492
# std     126.673177
# min      10.600000
# 25%      25.000000
# 50%      42.000000
# 75%      83.000000
# max    2300.000000

# %% [markdown]
# ## Missing Data

# %%
birds.isnull()
# Out:
#       Name  ScientificName  Category  Order  Family  Genus  \
# 0    False           False     False  False   False  False
# 1    False           False     False  False   False  False
# 2    False           False     False  False   False  False
# 3    False           False     False  False   False  False
# 4    False           False     False  False   False  False
# ..     ...             ...       ...    ...     ...    ...
# 438  False           False     False  False   False  False
# 439  False           False     False  False   False  False
# 440  False           False     False  False   False  False
# 441  False           False     False  False   False  False
# 442  False           False     False  False   False  False
#
#      ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 False      False      False        False        False
# 1                 False      False      False        False        False
# ...

# %%
birds.isnull().sum()
# Out:
# Name                  0
# ScientificName        0
# Category              0
# Order                 0
# Family                0
# Genus                 0
# ConservationStatus    0
# MinLength             0
# MaxLength             0
# MinBodyMass           0
# MaxBodyMass           0
# MinWingspan           0
# MaxWingspan           0
# dtype: int64

# %%
example1 = np.array([2, None, 6, 8])
example1
# Out:
# array([2, None, 6, 8], dtype=object)

# %%
example2 = np.array([2, np.nan, 6, 8]) 
example2.sum(), example2.min(), example2.max()
# Out:
# (nan, nan, nan)

# %% [markdown]
# ### NaN and None: null values in pandas

# %%
int_series = pd.Series([1, 2, 3], dtype=int)
int_series
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int32

# %% [markdown]
# ### Detecting null values

# %%
example3 = pd.Series([0, np.nan, '', None])
example3.isnull()
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
example3.isnull().sum()
# Out:
# 2

# %%
example3[example3.notnull()]
# Out:
# 0    0
# 2
# dtype: object

# %% [markdown]
# ### Dropping null values

# %%
example3 = example3.dropna()
example3
# Out:
# 0    0
# 2
# dtype: object

# %%
example4 = pd.DataFrame([[1,      np.nan, 7], 
                         [2,      5,      8], 
                         [np.nan, 6,      9]])
example4
# Out:
#      0    1  2
# 0  1.0  NaN  7
# 1  2.0  5.0  8
# 2  NaN  6.0  9

# %%
example4.dropna()
# Out:
#      0    1  2
# 1  2.0  5.0  8

# %%
example4.dropna(axis='columns')
# Out:
#    2
# 0  7
# 1  8
# 2  9

# %%
example4.dropna(axis='rows', thresh=3)
# Out:
#      0    1  2
# 1  2.0  5.0  8

# %% [markdown]
# ### Categorical Data(Non-numeric)

# %%
fill_with_mode = pd.DataFrame([[1,2,"True"],
                               [3,4,None],
                               [5,6,"False"],
                               [7,8,"True"],
                               [9,10,"True"]])

fill_with_mode
# Out:
#    0   1      2
# 0  1   2   True
# 1  3   4   None
# 2  5   6  False
# 3  7   8   True
# 4  9  10   True

# %%
fill_with_mode[2].value_counts()
# Out:
# 2
# True     3
# False    1
# Name: count, dtype: int64

# %%
fill_with_mode[2].fillna('True',inplace=True)
fill_with_mode
# Out:
#    0   1      2
# 0  1   2   True
# 1  3   4   True
# 2  5   6  False
# 3  7   8   True
# 4  9  10   True

# %% [markdown]
# ### Numeric Data

# %%
fill_with_mean = pd.DataFrame([[-2,0,1],
                               [-1,2,3],
                               [np.nan,4,5],
                               [1,6,7],
                               [2,8,9]])

fill_with_mean
# Out:
#      0  1  2
# 0 -2.0  0  1
# 1 -1.0  2  3
# 2  NaN  4  5
# 3  1.0  6  7
# 4  2.0  8  9

# %%
np.mean(fill_with_mean[0])
# Out:
# 0.0

# %%
fill_with_mean[0].fillna(np.mean(fill_with_mean[0]),inplace=True)
fill_with_mean
# Out:
#      0  1  2
# 0 -2.0  0  1
# 1 -1.0  2  3
# 2  0.0  4  5
# 3  1.0  6  7
# 4  2.0  8  9

# %%
fill_with_median = pd.DataFrame([[-2,0,1],
                               [-1,2,3],
                               [0,np.nan,5],
                               [1,6,7],
                               [2,8,9]])

fill_with_median
# Out:
#    0    1  2
# 0 -2  0.0  1
# 1 -1  2.0  3
# 2  0  NaN  5
# 3  1  6.0  7
# 4  2  8.0  9

# %%
fill_with_median[1].fillna(fill_with_median[1].median(),inplace=True)
fill_with_median
# Out:
#    0    1  2
# 0 -2  0.0  1
# 1 -1  2.0  3
# 2  0  4.0  5
# 3  1  6.0  7
# 4  2  8.0  9

# %%
example5 = pd.Series([1, np.nan, 2, None, 3], index=list('abcde'))
example5
# Out:
# a    1.0
# b    NaN
# c    2.0
# d    NaN
# e    3.0
# dtype: float64

# %%
example5.fillna(0)
# Out:
# a    1.0
# b    0.0
# c    2.0
# d    0.0
# e    3.0
# dtype: float64

# %%
birds.head(3)
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# 2                 LC       64.0       79.0       2050.0       4050.0
#
#    MinWingspan  MaxWingspan
# 0         76.0         94.0
# 1         85.0         93.0
# 2        135.0        165.0

# %% [markdown]
# ### ONE HOT ENCODING

# %%
# One hot enconding on the birds categorical variables
one_hot_data = pd.get_dummies(birds,columns=['Name',	'ScientificName',	'Category',	'Order',	'Family',	'Genus',	'ConservationStatus'])

# %%
one_hot_data
# Out:
#      MinLength  MaxLength  MinBodyMass  MaxBodyMass  MinWingspan  MaxWingspan  \
# 0         47.0       56.0        652.0       1020.0         76.0         94.0
# 1         45.0       53.0        712.0       1050.0         85.0         93.0
# 2         64.0       79.0       2050.0       4050.0        135.0        165.0
# 3         57.3       64.0       1066.0       1567.0        113.0        116.0
# 4         64.0       81.0       1930.0       3310.0        130.0        165.0
# ..         ...        ...          ...          ...          ...          ...
# 438       14.0       19.0         26.0         31.5         26.0         29.0
# 439       13.0       15.0         13.0         18.0         22.0         22.0
# 440       11.5       15.0         11.2         21.4         18.0         23.0
# 441       12.0       14.0         13.0         19.0         21.0         23.0
# 442       14.0       16.0         25.6         38.4         24.8         26.0
#
# ...

# %% [markdown]
# ### Removing duplicate data

# %%
birds.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 438    False
# 439    False
# 440    False
# 441    False
# 442    False
# Length: 443, dtype: bool

# %%
birds.drop_duplicates()
# Out:
#                              Name          ScientificName  \
# 0    Black-bellied whistling-duck  Dendrocygna autumnalis
# 1          Fulvous whistling-duck     Dendrocygna bicolor
# 2                      Snow goose      Anser caerulescens
# 3                    Ross's goose            Anser rossii
# 4     Greater white-fronted goose         Anser albifrons
# ..                            ...                     ...
# 438                 Blue grosbeak      Passerina caerulea
# 439                Lazuli bunting        Passerina amoena
# 440                Indigo bunting        Passerina cyanea
# 441               Painted bunting         Passerina ciris
# 442                    Dickcissel         Spiza americana
#
#                   Category          Order        Family        Genus  \
# 0    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# 1    Ducks/Geese/Waterfowl   Anseriformes      Anatidae  Dendrocygna
# ...
